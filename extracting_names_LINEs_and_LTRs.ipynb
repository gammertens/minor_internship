# %%
# import required modules
import scanpy
import os
import anndata
# Out:
# /Users/rocketman/opt/anaconda3/lib/python3.10/site-packages/scvi/_settings.py:63: UserWarning: Since v1.0.0, scvi-tools no longer uses a random seed by default. Run `scvi.settings.seed = 0` to reproduce results from previous versions.
#   self.seed = seed
# /Users/rocketman/opt/anaconda3/lib/python3.10/site-packages/scvi/_settings.py:70: UserWarning: Setting `dl_pin_memory_gpu_training` is deprecated in v1.0 and will be removed in v1.1. Please pass in `pin_memory` to the data loaders instead.
#   self.dl_pin_memory_gpu_training = (
# Global seed set to 0

# %%
# set working directory
new_dir = "/Volumes/Passport/CSDB/brain_scRNAseq/all_internship/"
os.chdir(new_dir)

# Verify the new working directory
updated_dir = os.getcwd()
print("Updated working directory:", updated_dir)
# Out:
# Updated working directory: /Volumes/Passport/CSDB/brain_scRNAseq/all_internship

# %%
# load in data for TE
TEs = sc.read_h5ad('data/processed/TE_concat.h5ad')
TEs
# Out:
# /Users/rocketman/opt/anaconda3/lib/python3.10/site-packages/anndata-0.9.1-py3.10.egg/anndata/_core/anndata.py:1830: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 144690 × 723

# %%
# extract names of all LINEs
names_LINEs = [name for name in TEs.var_names if name.endswith('LINE')]
names_LINEs
# Out:
# ['CR1-Mam:CR1:LINE',
#  'HAL1-SS:L1:LINE',
#  'HAL1:L1:LINE',
#  'HAL1M8:L1:LINE',
#  'HAL1ME:L1:LINE',
#  'HAL1b:L1:LINE',
#  'L1-Mm:L1:LINE',
#  'L1-Mur1:L1:LINE',
#  'L1-Mur2:L1:LINE',
#  'L1-Mur3:L1:LINE',
#  'L1-Mus1:L1:LINE',
#  'L1-Mus2:L1:LINE',
#  'L1-Mus3:L1:LINE',
#  'L1-Mus4:L1:LINE',
#  'L1-Rod:L1:LINE',
#  'L1M1:L1:LINE',
#  'L1M2:L1:LINE',
#  'L1M2a:L1:LINE',
#  'L1M2b:L1:LINE',
#  'L1M2c:L1:LINE',
#  'L1M3:L1:LINE',
#  'L1M3a:L1:LINE',
#  'L1M3c:L1:LINE',
#  'L1M3d:L1:LINE',
#  'L1M3de:L1:LINE',
#  'L1M3e:L1:LINE',
#  'L1M4:L1:LINE',
#  'L1M4a1:L1:LINE',
#  'L1M4a2:L1:LINE',
#  'L1M4b:L1:LINE',
#  'L1M4c:L1:LINE',
#  'L1M5:L1:LINE',
#  'L1M6:L1:LINE',
#  'L1M6B:L1:LINE',
#  'L1M7:L1:LINE',
#  'L1M8:L1:LINE',
#  'L1M:L1:LINE',
#  'L1MA10:L1:LINE',
#  'L1MA4:L1:LINE',
#  'L1MA4A:L1:LINE',
#  'L1MA5:L1:LINE',
#  'L1MA5A:L1:LINE',
#  'L1MA6:L1:LINE',
#  'L1MA7:L1:LINE',
#  'L1MA8:L1:LINE',
#  'L1MA9:L1:LINE',
#  'L1MB1:L1:LINE',
#  'L1MB2:L1:LINE',
#  'L1MB3:L1:LINE',
# ...

# %%
# write to file
with open('data/processed/LINEs.txt', 'w') as file:
    for item in names_LINEs:
        file.write(item + '\n')

# %%
# extract names of all LTRs
names_LTRs = [name for name in TEs.var_names if name.endswith('LTR')]
names_LTRs
# Out:
# ['BGLII-A:ERVK:LTR',
#  'BGLII-B2:ERVK:LTR',
#  'BGLII-B:ERVK:LTR',
#  'BGLII-C:ERVK:LTR',
#  'BGLII-Mur:ERVK:LTR',
#  'BGLII-Mus:ERVK:LTR',
#  'BGLII:ERVK:LTR',
#  'ERV3-16A3-I-int:ERVL:LTR',
#  'ERV3-16A3-LTR:ERVL:LTR',
#  'ERVB2-1-I-MM-int:ERVK:LTR',
#  'ERVB2-1A-I-MM-int:ERVK:LTR',
#  'ERVB3-1-I-MM-int:ERVK:LTR',
#  'ERVB3-1-LTR-MM:ERVK:LTR',
#  'ERVB4-1-I-MM-int:ERVK:LTR',
#  'ERVB4-1B-I-MM-int:ERVK:LTR',
#  'ERVB4-1B-LTR-MM:ERVK:LTR',
#  'ERVB4-1C-LTR-Mm:ERVK:LTR',
#  'ERVB4-2-I-MM-int:ERVK:LTR',
#  'ERVB4-2-LTR-MM:ERVK:LTR',
#  'ERVB4-3-I-MM-int:ERVK:LTR',
#  'ERVB4-3-LTR-MM:ERVK:LTR',
#  'ERVB5-1-I-MM-int:ERVK:LTR',
#  'ERVB5-1-LTR-MM:ERVK:LTR',
#  'ERVB5-2-LTR-MM:ERVK:LTR',
#  'ERVB7-1-LTR-MM:ERVK:LTR',
#  'ERVB7-2-LTR-MM:ERVK:LTR',
#  'ERVB7-2B-LTR-MM:ERVK:LTR',
#  'ERVB7-3-LTR-MM:ERVK:LTR',
#  'ERVB7-4-LTR-MM:ERVK:LTR',
#  'ERVL-B4-int:ERVL:LTR',
#  'ERVL-E-int:ERVL:LTR',
#  'ERVL-int:ERVL:LTR',
#  'ETnERV-int:ERVK:LTR',
#  'ETnERV2-int:ERVK:LTR',
# ...

# %%
# write to file
with open('data/processed/LTRs.txt', 'w') as file:
    for item in names_LTRs:
        file.write(item + '\n')
