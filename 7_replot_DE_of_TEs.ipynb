# %%
import os
import anndata as ad
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.chdir('/Volumes/Passport/CSDB/brain_scRNAseq/')

# %%
adata = sc.read_h5ad('all_internship/data/processed/annotated.h5ad')

# %%
sc.pl.umap(adata, color = 'RLTR18-int:ERVK:LTR', cmap = 'plasma', save = 'RLTR18_umap.png')
# Out:
# WARNING: saving figure to file figures/umapRLTR18_umap.png

# %%
sc.pl.umap(adata, color = 'MuRRS4-int:ERV1:LTR', cmap = 'plasma', save = 'MuRRS4_umap.png')
# Out:
# WARNING: saving figure to file figures/umapMuRRS4_umap.png

# %%
sc.pl.umap(adata, color = 'RLTR4-Mm:ERV1:LTR', cmap = 'plasma', save = 'RLTR4_umap.png')
# Out:
# WARNING: saving figure to file figures/umapRLTR4_umap.png
